# %%
import tweepy
import time
from ttictoc import tic,toc
import pandas as pd
import pickle
import csv
import json
import GetOldTweets3 as got
from tweepy import OAuthHandler
#from tweepy.streaming import StreamListener
import tweepy
import json
import pandas as pd
import csv
import re
from textblob import TextBlob
import string
import preprocessor as p
import os
import time

# %%
df = pd.read_csv('Dataset_1.csv')
df = df.drop('Unnamed: 0', axis = 1)

# %%
df
# Out:
#                  Tweet_ID                 Tweet_Time  \
# 0     1506836150358585348  2022-03-24 03:31:48+00:00
# 1     1506833849577521156  2022-03-24 03:22:40+00:00
# 2     1506826590340382721  2022-03-24 02:53:49+00:00
# 3     1506816555296124933  2022-03-24 02:13:56+00:00
# 4     1506813027059965954  2022-03-24 01:59:55+00:00
# ...                   ...                        ...
# 1326  1509635840594657284  2022-03-31 20:56:46+00:00
# 1327  1509512661758844933  2022-03-31 12:47:18+00:00
# 1328  1509495292344872967  2022-03-31 11:38:17+00:00
# 1329  1509476732520189954  2022-03-31 10:24:32+00:00
# 1330  1509470559939305473  2022-03-31 10:00:00+00:00
#
#                                              Tweet_Text  \
# 0     RT @Hogwarts_Acads: Hi guys! If you need any h...
# 1     Hi guys! If you need any help with acads, essa...
# 2     Hi guys! If you need any help with acads, essa...
# 3     I spoke about a topic very close to my heart: ...
# 4     RT @ninetakir: So I keep coming back to this q...
# ...                                                 ...
# 1326  I need to vent. Sometimes I feel so exhausted ...
# 1327  RT @CactusMHS: Things I wish people understood...
# 1328  RT @CactusMHS: Things I wish people understood...
# 1329  RT @CactusMHS: Things I wish people understood...
# 1330  Things I wish people understood about mental i...
#
#                                            Retweet_Text  \
# 0     Hi guys! If you need any help with acads, essa...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     So I keep coming back to this quote @SophiaBus...
# ...                                                 ...
# 1326                                                NaN
# 1327  Things I wish people understood about mental i...
# 1328  Things I wish people understood about mental i...
# 1329  Things I wish people understood about mental i...
# 1330                                                NaN
#
#                                          Tweet_HashTags  Total_Hashtags  \
# 0                                                  None               0
# 1      Essays essayhelp essaywriting AcademicChatter...               9
# 2      Essays essayhelp essaywriting AcademicChatter...               9
# 3                                  AcademicMentalHealth               1
# 4                                                  None               0
# ...                                                 ...             ...
# 1326   PhDChat PhDVoice AcademicTwitter AcademicChat...               5
# 1327                                               None               0
# 1328                                               None               0
# 1329                                               None               0
# 1330                               AcademicMentalHealth               1
#
#       Retweet_Count  Favorite_Count         Tweet_Source Retweet_Screen_Name  \
# 0                 1               0            publi2023      Hogwarts_Acads
# 1                 1               0  Twitter for Android                None
# 2                 0               0  Twitter for Android                None
# 3                 0               2   Twitter for iPhone                None
# 4                21               0  Twitter for Android           ninetakir
# ...             ...             ...                  ...                 ...
# 1326              1              13   Twitter for iPhone                None
# 1327             17               0  Twitter for Android           CactusMHS
# 1328             17               0  Twitter for Android           CactusMHS
# 1329             17               0      Twitter Web App           CactusMHS
# 1330             17              54      Twitter Web App            PhDVoice
#
#        Retweet_Account_ID Tweet_Lang              User_ID  User_ScreenName  \
# 0     1230985539953643521         en  1485693106204950530     academicsbot
# 1                    None         en  1230985539953643521   Hogwarts_Acads
# 2                    None         en  1499075530590613504       Nika_Acads
# 3                    None         en             41777476        symaahmed
# 4              1869041130         en  1320496981534453762     scigradcoach
# ...                   ...        ...                  ...              ...
# 1326                 None         en  1500226130648907777  Girlthescienti1
# 1327  1308276610949287941         en  1225070193099137025      BerlinMinds
# 1328  1308276610949287941         en   885778153733488640  Pauli_Ramirez_M
# 1329  1308276610949287941         en   748448023756169216       AndieAitch
# 1330  1168227245338628096         en  1308276610949287941        CactusMHS
#
#      Retweet_Source_ScreenName  Retweet
# 0               Hogwarts_Acads     True
# 1                         None    False
# 2                         None    False
# 3                         None    False
# 4                    ninetakir     True
# ...                        ...      ...
# 1326                      None    False
# 1327                 CactusMHS     True
# 1328                 CactusMHS     True
# 1329                 CactusMHS     True
# 1330                      None    False
#
# [1331 rows x 16 columns]
